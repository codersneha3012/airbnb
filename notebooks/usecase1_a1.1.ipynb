# %% [markdown]
# ## Finding Fake/Duplicate Records
#
# Commonly known as Data Dedupication & Record Linkage

# %%
# Download and unzip data
# !wget http://data.insideairbnb.com/united-kingdom/england/london/2023-03-14/data/listings.csv.gz -P ../data/
# !gunzip -kf ../data/listings.csv.gz

# %%
# !pip install nltk

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
import random
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/eessnin/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/eessnin/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from datetime import datetime, date
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import string
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import FeatureUnion, Pipeline
import re
import string
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer # or LancasterStemmer, RegexpStemmer, SnowballStemmer

default_stemmer = PorterStemmer()
default_stopwords = stopwords.words('english') # or any other list of your choice

# %matplotlib inline

# %%
df = pd.read_csv('../data/listings.csv')

# %%
df.head()
# Out:
#                    id                                      listing_url  \
# 0  714569379355913481  https://www.airbnb.com/rooms/714569379355913481
# 1  808038970516277767  https://www.airbnb.com/rooms/808038970516277767
# 2  822557738577472503  https://www.airbnb.com/rooms/822557738577472503
# 3             3518856             https://www.airbnb.com/rooms/3518856
# 4             4876550             https://www.airbnb.com/rooms/4876550
#
#         scrape_id last_scraped       source  \
# 0  20230314070633   2023-03-14  city scrape
# 1  20230314070633   2023-03-14  city scrape
# 2  20230314070633   2023-03-14  city scrape
# 3  20230314070633   2023-03-14  city scrape
# 4  20230314070633   2023-03-14  city scrape
#
#                                                 name  \
# 0            Lovely private bedroom in Muswell Hill.
# 1                       Studio Flat  Franklin London
# 2   PropertyPlug - 2Bed Flat in Edgware SmartTV WiFi
# 3                   Wimbledon Double Bedroom Ensuite
# 4  Stunning Apartment 2 minutes walk to Tube Station
#
#                                          description neighborhood_overview  \
# 0    Take a break and unwind at this peaceful oasis.                   NaN
# 1  Brand New Modern Kitchen<br />Close to Excelle...                   NaN
# 2  Enjoy easy access to everything from this perf...                   NaN
# 3  A welcoming and stylish 2 bedroom 2 bathroom f...                   NaN
# 4  Luxury Modern Apartment in modern development ...                   NaN
#
#                                          picture_url    host_id  ...  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...   39009854  ...
# 1  https://a0.muscache.com/pictures/miso/Hosting-...  495977998  ...
# 2  https://a0.muscache.com/pictures/d77957d5-695a...  325629338  ...
# 3  https://a0.muscache.com/pictures/23a18442-fc1d...     187811  ...
# 4  https://a0.muscache.com/pictures/miso/Hosting-...   25087384  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                         NaN                    NaN                 NaN
# 1                         NaN                    NaN                 NaN
# 2                         NaN                    NaN                 NaN
# 3                         5.0                   3.67                3.67
# 4                         NaN                    NaN                 NaN
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                f                              1
# 1     NaN                t                              7
# 2     NaN                t                              4
# 3     NaN                f                              2
# 4     NaN                f                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                           7
# 2                                           4
# 3                                           0
# 4                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            0
# 2                                            0
# 3                                            2
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0               NaN
# 1                                           0               NaN
# 2                                           0               NaN
# 3                                           0              0.05
# 4                                           0               NaN
#
# [5 rows x 75 columns]

# %%
# Since this is a data deduplication problem, we're interested in data uploaded by the host, let's print list of columns to find out those columns
df.shape
# Out:
# (75241, 75)

# %%
# Fillna
df['name'].fillna('', inplace=True)
df['description'].fillna('', inplace=True)

# %%
# tfidf calculation
text_content = df['name'] + ' ' + df['description']

#remove HTML tags
text_content = text_content.str.replace(r'<[^<>]*>', '', regex=True)

# Create vectorizer
vector = TfidfVectorizer(max_df=0.3,         # drop words that occur in more than X percent of documents
                             #min_df=8,      # only use words that appear at least X times
                             stop_words='english', # remove stop words
                             lowercase=True, # Convert everything to lower case 
                             use_idf=True,   # Use idf
                             norm=u'l2',     # Normalization
                             smooth_idf=True # Prevents divide-by-zero errors
                            )
tfidf = vector.fit_transform(text_content)

# %%
# Request function : search the top_n articles from a request ( request = string)
def search(tfidf_matrix,model,request, top_n = 5):
    request_transform = model.transform([request])
    similarity = np.dot(request_transform,np.transpose(tfidf_matrix))
    x = np.array(similarity.toarray()[0])
    indices=np.argsort(x)[-5:][::-1]
    return indices, x[indices]

# Find similar : get the top_n articles similar to an article 
def find_similar(tfidf_matrix, index, top_n = 5):
    cosine_similarities = linear_kernel(tfidf_matrix[index:index+1], tfidf_matrix).flatten()
    related_docs_indices = [i for i in cosine_similarities.argsort()[::-1] if i != index]
    return [index for index in related_docs_indices][0:top_n]    

# Print the result
def print_result(ind, request_content, indices, scores, X, min_score = 0.5):
    print('\nSearch : ' + str(ind) + ', ' + request_content)
    print('\nBest Results :')
    no_match = True
    for i in range(len(indices)):
        if (scores[i] > min_score) and (ind != indices[i]):
            no_match = False
            print('\nid = {0:5d} - {1} -> {2}'.format(indices[i], scores[i], X.loc[indices[i]]))
    if no_match:
        print('None')

# %%
# Minimum similarity score to qualify record as a match
MIN_MATCH_THRESHOLD = 0.6
# Number of tests to conduct 
NUM_RANDOM_TESTS = 15
test_indices = random.sample(range(len(text_content)), NUM_RANDOM_TESTS)
for ind in test_indices:
    print("---------------------------------------")
    request = text_content[ind]
    result, scores = search(tfidf,vector, request, top_n = 5)
    print_result(ind, request, result, scores, text_content, min_score=MIN_MATCH_THRESHOLD)
    print("---------------------------------------")
# Out:
# ---------------------------------------
#
# Search : 7947, Spacious Kensington Mews House This three-bedroom house is situated in the idyllic area of South Kensington. The property is also just 500 metres from Gloucester Road Underground Station, making this property the perfect location for your stay in London.The spaceLocated on the ground floor, this beautiful Central London house can comfortably accommodate up to eight people. The smoke-free property features a living room, three bedrooms, four bathrooms and a kitchen.The living room is equipped with a comfortable sofa, a dining table and a Smart TV. The kitchen is fully equipped with modern appliances and includes all the cooking utensils that you could need when preparing a quick snack or your evening dinner. The bedrooms are equipped with four double size beds, with bathrooms equipped with a bathtub with an overhead shower and two free-standing showers.To make the property feel like a home-away-from-home, we offer complimentary WiFi and our complimentary range of City
#
# Best Results :
#
# id = 37104 - 0.7725197093845724 -> Icon Tower Flat I This two-bedroom apartment is situated in the idyllic area of North Acton. The property is also just 250 metres from North Acton Underground Station, making this property the perfect location for your stay in London.The spaceLocated on the 27th floor, this beautiful London flat can comfortably accommodate up to four people. The smoke-free property features a living room, two bedrooms, two bathrooms, a kitchen, and a balcony. The living room is equipped with a comfortable sofa, a dining table and a Smart TV. The kitchen is fully equipped with modern appliances and includes all the cooking utensils that you could need when preparing a quick snack or your evening dinner. The bright bedrooms are equipped with a double and two single-size beds, with bathrooms equipped with a bathtub with an overhead shower and a free-standing shower. To make the property feel like a home-away-from-home, we offer complimentary WiFi and our complimentary range
#
# id = 42240 - 0.7643039803553597 -> Icon Tower Flat II This two bedroom apartment is situated in the idyllic area of North Acton. The property is also just 250 metres from North Acton Underground Station, making this property the perfect location for your stay in London.The spaceLocated on the 28th floor, this beautiful London flat can comfortably accommodate up to four people. The smoke-free property features a living room, two bedrooms, two bathrooms, a kitchen, and a balcony. The living room is equipped with a comfortable sofa, a dining table and a Smart TV. The kitchen is fully equipped with modern appliances and includes all the cooking utensils that you could need when preparing a quick snack or your evening dinner. The bright bedrooms are equipped with a double and two single-size beds, with bathrooms equipped with a bathtub with an overhead shower and a free-standing shower. To make the property feel like a home-away-from-home, we offer complimentary WiFi and our complimentary range
#
# id = 25901 - 0.757489125515581 -> Icon Tower Flat IV This two bedroom apartment is situated in the idyllic area of North Acton. The property is also just 250 metres from North Acton Underground Station, making this property the perfect location for your stay in London.The spaceLocated on the 31st floor, this beautiful London flat can comfortably accommodate up to four people. The smoke-free property features a living room, two bedrooms, two bathrooms, a kitchen, and a balcony. The living room is equipped with a comfortable sofa, a dining table and a Smart TV. The kitchen is fully equipped with modern appliances and includes all the cooking utensils that you could need when preparing a quick snack or your evening dinner. The bright bedrooms are equipped with a double and two single-size beds, with bathrooms equipped with a bathtub with an overhead shower and a free-standing shower. To make the property feel like a home-away-from-home, we offer complimentary WiFi and our complimentary range
#
# id = 46608 - 0.7469897386127567 -> Three Bedroom Kensington Flat Top floor three-bedroom apartment in Kensington, an ideal location for your stay in London.The spaceThis three-bedroom apartment is situated in the idyllic area of Kensington. The property is also just 180 metres from Kensington Olympia Underground, Overground and Train Station, making this property the perfect location for your stay in London.Located on the third floor, this beautiful London flat can comfortably accommodate up to six people. The smoke-free property features a living room, three bedrooms, two bathrooms, a kitchen, and a balcony.The living room is equipped with a comfortable sofa, a dining table and a Smart TV. The kitchen is fully equipped with modern appliances and includes all the cooking utensils that you could need when preparing a quick snack or your evening dinner. The bedrooms are equipped with a queen and two king-size beds, with bathrooms equipped with a bathtub with an overhead shower and a free-standing shower
# ---------------------------------------
# ---------------------------------------
#
# Search : 72999, Brilliant Baker Street Luxury Apartment Other things to note- We operate a flexible check in and out policy and can arrange for 24 hour check-in times but please let us know beforehand if you will need an arrival before midday or after 9pm / a check out after 3pm as we may need to charge an additional fee, depending on the circumstances. - We work very hard to make sure we’re punctual and available for checking in at a time that suits you best. We are here to help you to schedule an accurate check in time at the apartment, so please do use us to make sure your agreed check in time is as accurate as possible - please be aware that we can only guarantee to wait up to half an hour past your allotted check in time. Please let us know immediately of any delays as we can often work around issues with prior notice. We do charge £15 an hour for our staff waiting time once the half hour has passed, especially if we do not hear from you regarding delays before your scheduled time of arrival has passed. If we need to arran
#
# Best Results :
#
# id = 63310 - 0.7459525258871692 -> Prime Paddington 1 Bed with Terrace This beautiful and high end one bedroom property is professionally-managed and sits in an enviable location in Zone 1. It is set on a period street, right in the heart of London, a few minutes walk to Hyde Park. You can even watch the sunset from your own private balcony.Other things to noteNo parties or smoking in the apartment and please leave shoes off by the door :)We work very hard to make sure we’re punctual and available for checking in at a time that suits you best.  We are here to help you to schedule an accurate check in time at the apartment, so please do use us to make sure your agreed check in time is as accurate as possible -  please be aware that we can only wait up to one hour past you’re allotted check in time.  Please let us know immediately of any delays as we can often work around issues with prior notice.  We do charge £10 an hour for our staff waiting time once the hour has passed, especially if we do not hear from you re
#
# id = 63317 - 0.7316507767750523 -> Magical London 2Bed Mews House This is a professionally-managed cool and quirky 2 bedroom Mews house that stands out for its ultra modern design and spacious feel. You will certainly love it for its great location. Situated on a quiet brick road, this house has excellent - and we mean excellent - transport links.Guest accessGuests will have sole access to the entire home.Other things to noteWe work very hard to make sure we’re punctual and available for checking in at a time that suits you best.  We are here to help you to schedule an accurate check in time at the apartment, so please do use us to make sure your agreed check in time is as accurate as possible -  please be aware that we can only wait half an hour past you’re allotted check in time.  Please let us know immediately of any delays as we can often work around issues with prior notice.  We do charge £15 an hour for our staff waiting time once the half hour has passed, especially if we do not hear from you r
#
# id = 41193 - 0.6241799666733362 -> Westfields Central London Home  minutes from Tube A very beautifully designed one bedroom apartment full of character and charm. A few minutes walk to White City tube station,  just 15 minutes to Oxford Street Tube on the central line. Westfield shopping center is just around the corner making the apartment ideal for shoppers of visitors to London wanting  top benefit from a bustling local scene as well as great connections to the rest of the city.Guest accessGuests will have sole access to the whole apartmentOther things to noteWe work very hard to make sure we’re punctual and available for checking in at a time that suits you best.  We are here to help you to schedule an accurate check in time at the apartment, so please do use us to make sure your agreed check in time is as accurate as possible -  please be aware that we can only wait half an hour past you’re allotted check in time.  Please let us know immediately of any delays as we can often work around issues with prior notice.
# ---------------------------------------
# ---------------------------------------
#
# Search : 8847, Sunny double room in London Fields A lovely sunny room in a beautiful house well located for popular East London attractions including the markets, restaurants, bars and shops. A great area to explore with excellent transport links to the rest of the City.The spaceA lovely sunny and peaceful double room overlooking a beautiful secluded garden at the rear of my fully modernised three bedroom Victorian terraced house which is a great base from which to explore London's vibrant East End. My home has had a very stylish makeover with walnut, slate and limestone floors, big windows, high ceilings, lots of art on the walls and open plan lounge, kitchen and dining areas. The room is not huge but has a very comfortable bed, chest of drawers, hanging rail and space for your luggage. I will provide clean towels and bed linen on your arrival. Should you wish to spend time relaxing at home I have a large screen tv with cable channels, great music system, wi-fi, loads of books and plenty of  music
#
# Best Results :
# None
# ---------------------------------------
# ---------------------------------------
#
# Search : 53003, Large double room in central London This is a bedroom in a 3 bedroom apartment, available for 10 days rental (minimum 4 or 5 nights stay). It's on the first floor of a purpose build block, with plenty of natural light, always clean and organised, modern amenities.The spaceYou would be living with 2 lovely girls, one from France and the other one from Sweden. I'm renting my room only for a short period while I'm in Brazil for holidays.Guest accessThere are three fully furnished double bedrooms, a shower room and separate WC, modern kitchen and adjoining living room. You would have access to the kitchen, living room and toilet. The flat is small but really cozy - it is always clean and organised.
#
# Best Results :
# None
# ---------------------------------------
# ---------------------------------------
#
# Search : 73083, Lovely family style and charming 2-bedrooms flat! Welcome to my lovely 2-bedrooms apartment in Willesden Junction!Family friendly in Willesden Junction zone 2 close to Notting Hill, leafy residential area, brilliant value, very near to tubes and trains which are 10 minutes walk to the bakeloo line and Overground which is 20 minutes to Oxford Circus, 15 minutes to Wembley Stadium and just 10 min to the gorgeous Hindu Temple! One minute to the bus stop and plenty of convenience shops 1 min away!The spaceThe all apartment
#
# Best Results :
# None
# ---------------------------------------
# ---------------------------------------
# Search : 53023, King size Room nearby Central London/ Tourist Spot
#
# Best Results :
# None
# ---------------------------------------
# ---------------------------------------
#
# Search : 28780, Luxurious 2 bedroom flat with balcony London Welcome to our lovely 2 bed flat in the heart of East London. Minutes away from London Westfield, London Excel, Central London. WIFI is complimentary with a lovely smart TV for all your needs. We are here to make your stay as comfortable and accommodating as we possibly can. We are welcome to all guest's, please come and enjoy yourselves as best as you can.
#
# Best Results :
# None
# ---------------------------------------
# ---------------------------------------
#
# Search : 59959, Ladylights House Wembley Park Room 10 Nice double room in a newly refurbished town house with en-suite facilities, double bed, reading table, chest of draws wardrobe, lovely kitchen; 2 minutes walk from Wembley Park station, 5 minutes to Wembley Stadium!The spaceVery spaciuos house over 3 floors with 9 double rooms available. Suitable for groups. 2 minutes walk from Wembley Park station, 5 minutes to Wembley Stadium and London Designer Outlet for shopping! You can book for other rooms as well if you have more than 2 people that need to stay.Guest accessParking space for 2 cars available on a first come basis.
#
# Best Results :
#
# id = 25294 - 0.7927707879242042 -> Ladylights Room near Wembley Stadium with parking Nice double rooms in a lovely refurbished town house with modern en-suite facilities, double beds, reading table, chest of draws wardrobe, lovely kitchen; 2 minutes walk from Wembley Park station, 5 minutes to Wembley Stadium, the Designer outlet and other shopping facilities.
#
# id = 17538 - 0.7837932398113608 -> Ladylights Room 8 Near Wembley Stadium Nice double room in a lovely refurbished town house with modern en-suite facilities, double beds, reading table, chest of draws wardrobe, lovely kitchen; 2 minutes walk from Wembley Park station, 5 minutes to Wembley Stadium, the Designer outlet and other shopping facilities.
#
# id = 25293 - 0.719096577140256 -> Ladylights Room7 near Wembley Stadium with parking Nice double room in a lovely refurbished town house with modern facilities, double beds, reading table, chest of draws wardrobe, lovely kitchen; 2 minutes walk from Wembley Park station, 5 minutes to Wembley Stadium, the Designer outlet and other shopping facilities.
#
# id = 51887 - 0.6560184677730896 -> Ladylights House Wembley Park Room 4 Nice double room with modern ensuite facilities, double bed, reading table, chest of draws wardrobe, lovely kitchen and 2 minutes walk from Wembley Park station.The spaceMultiple rooms available. Suitavle for groups.Guest accessParking space for 2 cars available on a first come basis.
# ---------------------------------------
# ---------------------------------------
#
# Search : 57533, Stylish double room with smart TV #B Centrally located, spacious and cosy double room with Smart TV. Excellent transportation links available within walking distance from the accomadation. This location is the ideal place for both travellers wanting to explore london and is highly convenient for professionals working in the area or near by. Explore the area to find a variety of nearby eateries as well as leisure activites, or if your simply looking for a place to relax and unwind, this is the place for you. (SHARED ACCOMMODATION)The spaceAbout the room:The room comes with a double sized bed with comfortable highly qualith mattress and luxury bedding. A smart tv with access to Netflix, youtube, amazon and much more is also installed in the room.  This a spacious private room that is ideal for short and long stays. Guests can expect to have access to clean bedding, towels, hair dryer, iron etc. if further items are required always easy to contact host who is happy to accommodate. this is a SHA
#
# Best Results :
# None
# ---------------------------------------
# ---------------------------------------
#
# Search : 49311, OFF-GRID COZY CAMPERVAN Get away from it all when you stay under the stars, discover new places, drive through the country side and enjoy a memorable timeThe van has been converted into a comfortable space for two people to travel long term and short term.It counts with:- Solar panels and leisurebattery-Fitted kitchen with two gas stoves and a sink-Wood burning stove for heating-Sofa bed for two-Shower/toilet area. -Closet and over head storage units-Extra storage in the trunk for luggage.
#
# Best Results :
# None
# ---------------------------------------
# ---------------------------------------
#
# Search : 11792, Brilliant home Enjoy a stylish experience at this centrally-located place.
#
# Best Results :
#
# id = 70094 - 0.7145134840984599 -> D’s place Enjoy a stylish experience at this centrally-located place.
#
# id = 14711 - 0.7094538768257622 -> Double bedroom in Top floor  apartment Enjoy a stylish experience at this centrally-located place.
#
# id = 30922 - 0.7085826861069969 -> 1 Private room in Central London Enjoy a stylish experience at this centrally-located place.
#
# id =  3235 - 0.7080186723850511 -> Modern apartment Enjoy a stylish experience at this centrally-located place.
# ---------------------------------------
# ---------------------------------------
#
# Search : 69739, Delphina - Spacious 2BR Modern Maisonette Relax, Live & Work in your space with Oval. You will love our Delphina flat. Featuring a spacious live/work area and a fully equipped open kitchen you will be extremely comfortable in this spacious apartment. King Size beds, High-quality mattresses, and luxe-cotton linens and towels will ensure you have a pampered stay. There is an abundance of local amenities and the apartment is a minute's walk to Turnpike Lane London Underground station, ensuring convenient access to the rest of the city.The spaceAll Oval properties are thoughtfully designed for your maximum comfort and enjoyment. Delphina features everything you will need from Super Fast Wifi and Smart TV to a fully equipped open-style kitchen and luxurious towels and linens. We take any stress out of your stay by providing everything you might need to feel full at home. Two spacious double bedrooms split across two floors ensure Delphina offers ample space to relax in the open living area and kitchen. This
#
# Best Results :
# None
# ---------------------------------------
# ---------------------------------------
#
# Search : 27959, Fantastic New 1 Bedroom Flat in Stockwell Welcome to my lovely one bedroom flat in Stockwell!This is a new and fully-equipped apartment, located just 10 minutes walk from Stockwell Underground station (Northern and Victoria lines) and offering excellent connections into central London.Perfect for couples, friends or even business visitors - everyone welcome!The spaceThe living room is perfect for relaxing after a long day exploring London: it features a comfortable sofa and a TV with Freeview channels to keep you entertained. You also have access to an adjacent balcony - great for having that morning cup of coffee.Feel free to take advantage of the fully equipped kitchen (although London is famous for its world-class bars and restaurants - be sure to check out the Guidebook section for some of my personal recommendations!).In the bedroom you will find a plush king-size bed as well as some storage space for your clothes and luggage. My cleaners place fresh
#
# Best Results :
# None
# ---------------------------------------
# ---------------------------------------
#
# Search : 32840, Spacious Flat 3 bedroom London Spacious Flat with the best location in the great City of London, few steps from restaurants, supermarkets. Equipped for a maximum of 6 people.
#
# Best Results :
# None
# ---------------------------------------
# ---------------------------------------
#
# Search : 56000, Lovely bedroom. Walk to Tower Bridge! Peaceful and centrally-located bedroom in a modern fully equipped two bedroom flat.  Gym and terrace with great views in the building.Only 10MINS WALK TO:-Tower Bridge-Brick Lane-Shoreditch-Tower Hill, Aldgate East, Shadwell and Whitechapel stations-Saint Katherine's DockWe have all you need in the flat, from iron, to coffee, towels, hair dryer, dishwasher, washing machine, toaster, microwave and all those essentials you will need to cook and get ready to go out to explore the city.
#
# Best Results :
# None
# ---------------------------------------
