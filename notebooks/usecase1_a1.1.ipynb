# %% [markdown]
# ## Finding Fake/Duplicate Records
#
# Commonly known as Data Dedupication & Record Linkage

# %%
# Download and unzip data
# !wget http://data.insideairbnb.com/united-kingdom/england/london/2023-03-14/data/listings.csv.gz -P ../data/
# !gunzip -kf ../data/listings.csv.gz

# %%
# !pip install nltk

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
import random
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/eessnin/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/eessnin/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
from datetime import datetime, date
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import string
import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import FeatureUnion, Pipeline
import re
import string
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer # or LancasterStemmer, RegexpStemmer, SnowballStemmer

default_stemmer = PorterStemmer()
default_stopwords = stopwords.words('english') # or any other list of your choice

# %matplotlib inline

# %%
df = pd.read_csv('../data/listings.csv')

# %%
df.head()
# Out:
#                    id                                      listing_url  \
# 0  714569379355913481  https://www.airbnb.com/rooms/714569379355913481
# 1  808038970516277767  https://www.airbnb.com/rooms/808038970516277767
# 2  822557738577472503  https://www.airbnb.com/rooms/822557738577472503
# 3             3518856             https://www.airbnb.com/rooms/3518856
# 4             4876550             https://www.airbnb.com/rooms/4876550
#
#         scrape_id last_scraped       source  \
# 0  20230314070633   2023-03-14  city scrape
# 1  20230314070633   2023-03-14  city scrape
# 2  20230314070633   2023-03-14  city scrape
# 3  20230314070633   2023-03-14  city scrape
# 4  20230314070633   2023-03-14  city scrape
#
#                                                 name  \
# 0            Lovely private bedroom in Muswell Hill.
# 1                       Studio Flat  Franklin London
# 2   PropertyPlug - 2Bed Flat in Edgware SmartTV WiFi
# 3                   Wimbledon Double Bedroom Ensuite
# 4  Stunning Apartment 2 minutes walk to Tube Station
#
#                                          description neighborhood_overview  \
# 0    Take a break and unwind at this peaceful oasis.                   NaN
# 1  Brand New Modern Kitchen<br />Close to Excelle...                   NaN
# 2  Enjoy easy access to everything from this perf...                   NaN
# 3  A welcoming and stylish 2 bedroom 2 bathroom f...                   NaN
# 4  Luxury Modern Apartment in modern development ...                   NaN
#
#                                          picture_url    host_id  ...  \
# 0  https://a0.muscache.com/pictures/miso/Hosting-...   39009854  ...
# 1  https://a0.muscache.com/pictures/miso/Hosting-...  495977998  ...
# 2  https://a0.muscache.com/pictures/d77957d5-695a...  325629338  ...
# 3  https://a0.muscache.com/pictures/23a18442-fc1d...     187811  ...
# 4  https://a0.muscache.com/pictures/miso/Hosting-...   25087384  ...
#
#   review_scores_communication review_scores_location review_scores_value  \
# 0                         NaN                    NaN                 NaN
# 1                         NaN                    NaN                 NaN
# 2                         NaN                    NaN                 NaN
# 3                         5.0                   3.67                3.67
# 4                         NaN                    NaN                 NaN
#
#   license instant_bookable calculated_host_listings_count  \
# 0     NaN                f                              1
# 1     NaN                t                              7
# 2     NaN                t                              4
# 3     NaN                f                              2
# 4     NaN                f                              1
#
#   calculated_host_listings_count_entire_homes  \
# 0                                           0
# 1                                           7
# 2                                           4
# 3                                           0
# 4                                           1
#
#   calculated_host_listings_count_private_rooms  \
# 0                                            1
# 1                                            0
# 2                                            0
# 3                                            2
# 4                                            0
#
#   calculated_host_listings_count_shared_rooms reviews_per_month
# 0                                           0               NaN
# 1                                           0               NaN
# 2                                           0               NaN
# 3                                           0              0.05
# 4                                           0               NaN
#
# [5 rows x 75 columns]

# %%
# Since this is a data deduplication problem, we're interested in data uploaded by the host, let's print list of columns to find out those columns
df.shape
# Out:
# (75241, 75)

# %%
# Fillna
df['name'].fillna('', inplace=True)
df['description'].fillna('', inplace=True)

# %%
# tfidf calculation
text_content = df['name'] + ' ' + df['description']

#remove HTML tags
text_content = text_content.str.replace(r'<[^<>]*>', '', regex=True)

# Create vectorizer
vector = TfidfVectorizer(max_df=0.3,         # drop words that occur in more than X percent of documents
                             #min_df=8,      # only use words that appear at least X times
                             stop_words='english', # remove stop words
                             lowercase=True, # Convert everything to lower case 
                             use_idf=True,   # Use idf
                             norm=u'l2',     # Normalization
                             smooth_idf=True # Prevents divide-by-zero errors
                            )
tfidf = vector.fit_transform(text_content)

# %%
# Request function : search the top_n articles from a request ( request = string)
def search(tfidf_matrix,model,request, top_n = 5):
    request_transform = model.transform([request])
    similarity = np.dot(request_transform,np.transpose(tfidf_matrix))
    x = np.array(similarity.toarray()[0])
    indices=np.argsort(x)[-5:][::-1]
    return indices, x[indices]

# Find similar : get the top_n articles similar to an article 
def find_similar(tfidf_matrix, index, top_n = 5):
    cosine_similarities = linear_kernel(tfidf_matrix[index:index+1], tfidf_matrix).flatten()
    related_docs_indices = [i for i in cosine_similarities.argsort()[::-1] if i != index]
    return [index for index in related_docs_indices][0:top_n]    

# Print the result
def print_result(ind, request_content, indices, scores, X, min_score = 0.5):
    print('\nSearch : ' + str(ind) + ', ' + request_content)
    print('\nBest Results :')
    no_match = True
    for i in range(len(indices)):
        if (scores[i] > min_score) and (ind != indices[i]):
            no_match = False
            print('\nid = {0:5d} - {1} -> {2}'.format(indices[i], scores[i], X.loc[indices[i]]))
    if no_match:
        print('None')

# %%
# Minimum similarity score to qualify record as a match
MIN_MATCH_THRESHOLD = 0.6
# Number of tests to conduct 
NUM_RANDOM_TESTS = 15
test_indices = random.sample(range(len(text_content)), NUM_RANDOM_TESTS)
for ind in test_indices:
    print("---------------------------------------")
    request = text_content[ind]
    result, scores = search(tfidf,vector, request, top_n = 5)
    print_result(ind, request, result, scores, text_content, min_score=MIN_MATCH_THRESHOLD)
    print("---------------------------------------")
# Out:
# ---------------------------------------
#
# Search : 13829, Central London, Big Room W/ Garden Modern, cozy house in central London, in green estate with trees and parks close by.Massive spacious room. Patio doors opens to large garden space which is rarely used.Great location 5/10 minute bus or tube to Westminster/SohoCity or ClaphamThe spaceThe room being rented is the room overlooking the garden as shown.  The room is on the ground floor where the other 3 bedrooms are upstairs.You will be right next to a downstairs toilet which is handy as the second toilet and shower room is upstairs.Guest accessYou can use kitchen and the bath/shower room and toilet upstairs. There is a toilet downstairs next to the room you'll be staying in.
#
# Best Results :
# None
# ---------------------------------------
# ---------------------------------------
#
# Search : 1188, Cosy Room W/ Home Music Studio Setup This is a private room for artists looking for a cosy space w/facilities to hold small music sessions and record rough demos during your stay.  There are no sound or time restrictions. There are other rooms in the unit with the same allowances.Space limited to 4 people at a time.The space includes a double mattress, 2 sofas, a television with connection capabilities via hdmi, plug and play soundcard, wifi as well as access to a shared shower and small kitchenette.30 mins from Central LondonThe spaceThis space consists of a private medium sized room as shown in the pictures.A shower room/toilet which is shared with other housemates.The kitchenette does includes a sink, juicer, nutri-bullet blender, microwave, mini oven, pressure cooker, air fryer, cups, plates/bowls and cutlery, however there is no hob or stove to cook on. The shower room has a toilet, sink and a small showerPlease be aware, the room does not
#
# Best Results :
# None
# ---------------------------------------
# ---------------------------------------
#
# Search : 73045, 4 Bedroom house  - 15 mins to Central London Four bedroom townhouse on a quiet residential street a block away from the High street - Salusbury Road. Newly converted with a brand new kitchen and bathroom. Perfect for a family of four to seven who want to be in a friendly area with easy access to central London.The spaceLovely quiet house down a side-street within 150 metres of Queen Park High street.Guest accessWhole house is yours -  apart from the office  - which will be locked.
#
# Best Results :
# None
# ---------------------------------------
# ---------------------------------------
#
# Search : 18759, Lovely Spacious Quiet Flat-CENTRAL- near Kings X Lovely bright newly built flat in quiet but central location. Very clean and bright and close to some of London's best neighborhoods, including the world class Kings X with lovely canals, restaurants, shops, parks, and street markets! Great transport- bus, tube & rail (1 stop from Kings X with many travel options)- direct from Heathrow on the Piccadilly line, plus good shops and restaurants within walking distance. Islington, Kings X, and Camden nearby.The spaceThis is a lovely bright spacious newly built flat in a quiet but central location- very clean, minimal yet cosy, open plan, bright, and spacious and secure (video intercom plus secure keyless front entry to the building).  It is very quiet and a great place to unwind after visiting London's sites.  Great access to transportation. 1 stop to Kings X, 2 stops direct on the tube to Russell Square (Bloomsbury).Beautifully and minimally furnished with leather couches for a peaceful relaxing stay wh
#
# Best Results :
# None
# ---------------------------------------
# ---------------------------------------
#
# Search : 20650, Cosy flat with a balcony & garden access This space was part of a small five-flat project that was built only last year and completed in March. It's a beautiful and brand new, ground floor flat, and so are all the appliances & furniture. Composed of a spacious living room, kitchen, bathroom, a bedroom with a comfortable king size bed, and a private terrace with access to a garden.I added the flat on here on  Nov22, so still gathering not many reviews, but I have over 50 reviews as both a guest and a host for over 8 years on Airbnb!Guest accessThe entire flat
#
# Best Results :
# None
# ---------------------------------------
# ---------------------------------------
#
# Search : 3091, 1 bed ensuite in a 9bedroom house Lovely 1 bed room in a 9 bedroomhouse, spacious and clean
#
# Best Results :
# None
# ---------------------------------------
# ---------------------------------------
#
# Search : 73530, 2-Bedroom Apartment w/Good Transport & View Backing onto the tranquil green space of Alexandra Palace park, this two-bedroom apartment is situated on a leafy residential road in North London. The front room fills with sunlight and has a lovely balcony view to the north. I have had many families (with young children) stay here, as well as couples and groups of friends. They love the quietness of the neighbourhood and the nearby transport into central London.
#
# Best Results :
#
# id = 63809 - 0.9999999999999998 -> 2-Bedroom Apartment with View and Good Transport Backing onto the tranquil green space of Alexandra Palace park, this two-bedroom apartment is situated on a leafy residential road in North London. The front room fills with sunlight and has a lovely balcony view to the north.I have had many families (with young children) stay here, as well as couples and groups of friends. They love the quietness of the neighbourhood and the nearby transport into central London.
#
# id =   573 - 0.6905791345348935 -> 2-Bedroom Apartment with a View Backing onto the tranquil green space of Alexandra Palace park, this two-bedroom apartment is situated on a leafy residential road in North London. The front room fills with sunlight and has a lovely balcony view to the north.Guest accessYou will have access to the entire apartment (two bedrooms, bathroom, living/dining room and kitchen), and to the rear garage if this is required.
# ---------------------------------------
# ---------------------------------------
#
# Search : 69009, Fantastic twin/double room in ACTON  free  parking Really lovely decorated double room in a very nice ground floor flat of a converted house, private entrance,free off street parking . Very nice road with local shops and takeaways approx 2 mins and High St 10 mins  walk.  It is convenient to several tube/train stations:Acton Main line 3 mins walk takes to Heathrow airport and paddington station Central line 10 mins to Westfield shopping centre Shepherds BushPiccadilly and District lines Acton Central  train Bus 266 bottom of roadThe spaceAlthough the room has 2 single beds they can be very easily joined together for couples. You can use the  left hand off street parking space .A basic  self service breakfast will be included,facilities will be provided in your room for tea and coffee. You can use the kitchen up until 21:00 hrs and you can use the dinning table  in the lounge.Guest accessBedroom, kitchen,bathroom and dinning table in the lounge.
#
# Best Results :
# None
# ---------------------------------------
# ---------------------------------------
#
# Search : 2115, Spacious Holland Park Flat A large ground floor flat in West London, with two double bedrooms, in relatively good condition, accompanied by small private outside area. Our home is 12 minutes walk from Holland Park station and 8 minute walk from Latimer Road.
#
# Best Results :
# None
# ---------------------------------------
# ---------------------------------------
#
# Search : 36330, Cozy Private Double Room in a Brand New Home Cozy Private Double bedroom in a newly built property. Features:- Very quiet location- Free parking - Super fast fibre optic broadband -  Modern furnishing- Work station (Desk and chair)- 5 minute walk from Rainham train station - 25 minutes direct train ride to London Fenchurch street station - Easy & close access to M25 & A13- Easy & close to Dartfort crossing- Tesco super store four minute walk from property- Breakfast Included (bread, butter/jam, tea, coffee, milk)Guest accessGuests can access the first floor and ground floor. The topmost floor is out of bounds to guests
#
# Best Results :
#
# id = 35953 - 0.8926688377093175 -> Private Queen Sized Room in a Brand New Home Queen sized bedroom in a newly built property. Features:- Very quiet location- Free parking - Super fast fibre optic broadband -  Modern furnishing- Work station (Desk and chair)- 5 minutes walk from Rainham train station - 25 minutes direct train ride to London Fenchurch street station - Easy & close access to M25 & A13- Easy & close to Dartfort crossing- 5 minutes walk to Tesco Superstore- Breakfast Included (bread, butter/jam, tea, coffee, milk)Guest accessGuests can access the first floor and ground floor. The topmost floor is out of bounds to guests
# ---------------------------------------
# ---------------------------------------
#
# Search : 65854, Sunny, Islington, couple’s flat A cosy 1 bed flat on the top floor of a classic Victorian townhouse in Islington, 15 minutes from Camden Town and 20 minutes from Oxford Circus. We live here so it will be full of our things but that means you’ll have a fully stocked kitchen!The spaceOur flat is small but sunny. It's full of our things as it is a lived-in flat but we'll make space for your stuff. There will be oil, salt, pepper, herbs and more so you don't need to buy those things that you always throw away at the end of the trip if you like to cook for yourself. You'll also have WIFI and a hairdryer and hair straighteners if you'd like to use them!Guest accessYou'll have the whole apartment to yourself. We're on holiday.
#
# Best Results :
# None
# ---------------------------------------
# ---------------------------------------
# Search : 12974, Beautiful and clean room in Hackney Beautiful bedroom available in a terraced house located on a quiet street in the best spot of Hackney just in between London Fields and De Beauvoir. Wooden floors, new bed and lots of light.The spaceThe bedroom has a large south-facing window which ensures plenty of day light. It has just been refurbished with wooden floor. Furniture are brand new (bed, mattress, bedside table, desk and a large armchair). It comes with a private bathroom  just next door (where you can enjoy a hot tub)!Other things to notePlease let us know if you have any question or if you need any info.  we will be happy to help and share with you some tips on bars/restaurant and the local area.
#
# Best Results :
# None
# ---------------------------------------
# ---------------------------------------
#
# Search : 32269, A cosy double bedroom (Olympic Park and Westfield) Looking for a comfortable place to stay not far from Central London? Then your search ends here. We offer: a cosy double bedroom and a big 3-piece bathroom (wash basin, W/C and bath facilities). Shared areas: Full kitchen, living room and diner shared with the hosts. Neighbourhood: residential area with easy access to Stratford station, Olympic park and Central London. So, pack your bags and book with us today for a great experience in London.We look forward to hosting you!The spaceOur property is located in a quiet residential area which is 2-min away from a bus stop and 10-minutes away from the Stratford station (which has Central Line, Jubilee Line, Overground Trains and DLR). This makes it easily accessible from all parts of London. The property has wonderful views of river side from the living area and of Arcelor Mittal Orbit (Olympic Park) from the bedroom.Although you will share the house with my small family, you will have your o
#
# Best Results :
#
